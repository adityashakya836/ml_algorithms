# %%
import pandas as pd
import numpy as np
import spacy
from spacy.lang.en.stop_words import STOP_WORDS as stopwords

# %%
df = pd.read_csv('https://raw.githubusercontent.com/laxmimerit/twitter-data/master/twitter4000.csv', encoding = 'latin1')

# %%
df.head()
# Out:
#                                               twitts  sentiment
# 0  is bored and wants to watch a movie  any sugge...          0
# 1           back in miami.  waiting to unboard ship           0
# 2  @misskpey awwww dnt dis brng bak memoriessss, ...          0
# 3                  ughhh i am so tired  blahhhhhhhhh          0
# 4  @mandagoforth me bad! It's funny though. Zacha...          0

# %%
df.tail()
# Out:
#                                                  twitts  sentiment
# 3995                                  i just graduated           1
# 3996          Templating works; it all has to be done            1
# 3997                   mommy just brought me starbucks           1
# 3998  @omarepps watching you on a House re-run...lov...          1
# 3999  Thanks for trying to make me smile I'll make y...          1

# %%
df.shape
# Out:
# (4000, 2)

# %%
df['sentiment'].value_counts()
# Out:
# 0    2000
# 1    2000
# Name: sentiment, dtype: int64

# %% [markdown]
# # Word Counts

# %%
len('this is text'.split())
# Out:
# 3

# %%
df
# Out:
#                                                  twitts  sentiment
# 0     is bored and wants to watch a movie  any sugge...          0
# 1              back in miami.  waiting to unboard ship           0
# 2     @misskpey awwww dnt dis brng bak memoriessss, ...          0
# 3                     ughhh i am so tired  blahhhhhhhhh          0
# 4     @mandagoforth me bad! It's funny though. Zacha...          0
# ...                                                 ...        ...
# 3995                                  i just graduated           1
# 3996          Templating works; it all has to be done            1
# 3997                   mommy just brought me starbucks           1
# 3998  @omarepps watching you on a House re-run...lov...          1
# 3999  Thanks for trying to make me smile I'll make y...          1
#
# [4000 rows x 2 columns]

# %%
df['word_counts'] = df['twitts'].apply(lambda x : len(str(x).split()))

# %%
df.sample(5)
# Out:
#                                                  twitts  sentiment  \
# 730   @_skp   @_skp time to die..lets jump off the t...          0
# 1024  @CelestialAxis I feel for the Muppets skinned ...          0
# 66    @anthothemantho hahaha i agree! i cried like a...          0
# 2903             @CampNicole You've made my day again.           1
# 1394  @nkotb Okay, so I liked the show. Enjoy it a l...          0
#
#       word_counts
# 730            21
# 1024           12
# 66             16
# 2903            6
# 1394           15

# %%
df['word_counts'].max()
# Out:
# 32

# %%
df['word_counts'].min()
# Out:
# 1

# %%
df[df['word_counts']==1]
# Out:
#                                twitts  sentiment  word_counts
# 385                         homework           0            1
# 691                         @ekrelly           0            1
# 1124                    disappointed           0            1
# 1286                 @officialmgnfox           0            1
# 1325                        headache           0            1
# 1897                      @MCRmuffin           0            1
# 2542                      Graduated!           1            1
# 2947                         reading           1            1
# 3176                    @omeirdeleon           1            1
# 3470  www.myspace.com/myfinalthought           1            1
# 3966                        @gethyp3           1            1

# %% [markdown]
# # Character Counts

# %%
def char_counts(x):
  s = x.split()
  x = ''.join(s)
  return len(x)

# %%
df['char_counts'] = df['twitts'].apply(lambda x : char_counts(str(x)))

# %% [markdown]
# # Average Word Length

# %%
df
# Out:
#                                                  twitts  sentiment  \
# 0     is bored and wants to watch a movie  any sugge...          0
# 1              back in miami.  waiting to unboard ship           0
# 2     @misskpey awwww dnt dis brng bak memoriessss, ...          0
# 3                     ughhh i am so tired  blahhhhhhhhh          0
# 4     @mandagoforth me bad! It's funny though. Zacha...          0
# ...                                                 ...        ...
# 3995                                  i just graduated           1
# 3996          Templating works; it all has to be done            1
# 3997                   mommy just brought me starbucks           1
# 3998  @omarepps watching you on a House re-run...lov...          1
# 3999  Thanks for trying to make me smile I'll make y...          1
#
#       word_counts  char_counts
# 0              10           43
# 1               7           32
# 2              12           54
# 3               6           27
# 4              26          116
# ...           ...          ...
# 3995            3           14
# 3996            8           32
# 3997            5           27
# 3998            8           45
# 3999           16           63
#
# [4000 rows x 4 columns]

# %%
df['avg_word_length'] = df['char_counts']/df['word_counts']

# %%
df.sample(5)
# Out:
#                                                  twitts  sentiment  \
# 124        Fuck off, Rafa.  Broken serving for the set?          0
# 3809                  1 bottle of win is enough for me           1
# 1773  @MissRios86 im sorry i didnt kno you was marri...          0
# 692   @SmallSlice Nope   I'm not a fan of the Carrot...          0
# 566   trying to come to terms with the fact that I n...          0
#
#       word_counts  char_counts  avg_word_length
# 124             8           36         4.500000
# 3809            8           25         3.125000
# 1773           22           81         3.681818
# 692            11           46         4.181818
# 566            22           80         3.636364

# %% [markdown]
# # Stop Words Count

# %%
stopwords
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
#  'everyone',
#  'everything',
#  'everywhere',
#  'except',
#  'few',
#  'fifteen',
#  'fifty',
#  'first',
#  'five',
#  'for',
#  'former',
#  'formerly',
#  'forty',
#  'four',
#  'from',
#  'front',
#  'full',
#  'further',
#  'get',
#  'give',
#  'go',
#  'had',
#  'has',
#  'have',
#  'he',
#  'hence',
#  'her',
#  'here',
#  'hereafter',
#  'hereby',
#  'herein',
#  'hereupon',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'however',
#  'hundred',
#  'i',
#  'if',
#  'in',
#  'indeed',
#  'into',
#  'is',
#  'it',
#  'its',
#  'itself',
#  'just',
#  'keep',
#  'last',
#  'latter',
#  'latterly',
#  'least',
#  'less',
#  'made',
#  'make',
#  'many',
#  'may',
#  'me',
#  'meanwhile',
#  'might',
#  'mine',
#  'more',
#  'moreover',
#  'most',
#  'mostly',
#  'move',
#  'much',
#  'must',
#  'my',
#  'myself',
#  "n't",
#  'name',
#  'namely',
#  'neither',
#  'never',
#  'nevertheless',
#  'next',
#  'nine',
#  'no',
#  'nobody',
#  'none',
#  'noone',
#  'nor',
#  'not',
#  'nothing',
#  'now',
#  'nowhere',
#  'n‘t',
#  'n’t',
#  'of',
#  'off',
#  'often',
#  'on',
#  'once',
#  'one',
#  'only',
#  'onto',
#  'or',
#  'other',
#  'others',
#  'otherwise',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'part',
#  'per',
#  'perhaps',
#  'please',
#  'put',
#  'quite',
#  'rather',
#  're',
#  'really',
#  'regarding',
#  'same',
#  'say',
#  'see',
#  'seem',
#  'seemed',
#  'seeming',
#  'seems',
#  'serious',
#  'several',
#  'she',
#  'should',
#  'show',
#  'side',
#  'since',
#  'six',
#  'sixty',
#  'so',
#  'some',
#  'somehow',
#  'someone',
#  'something',
#  'sometime',
#  'sometimes',
#  'somewhere',
#  'still',
#  'such',
#  'take',
#  'ten',
#  'than',
#  'that',
#  'the',
#  'their',
#  'them',
#  'themselves',
#  'then',
#  'thence',
#  'there',
#  'thereafter',
#  'thereby',
#  'therefore',
#  'therein',
#  'thereupon',
#  'these',
#  'they',
#  'third',
#  'this',
#  'those',
#  'though',
#  'three',
#  'through',
#  'throughout',
#  'thru',
#  'thus',
#  'to',
#  'together',
#  'too',
#  'top',
#  'toward',
#  'towards',
#  'twelve',
#  'twenty',
#  'two',
#  'under',
#  'unless',
#  'until',
#  'up',
#  'upon',
#  'us',
#  'used',
#  'using',
#  'various',
#  'very',
#  'via',
#  'was',
#  'we',
#  'well',
#  'were',
#  'what',
#  'whatever',
#  'when',
#  'whence',
#  'whenever',
#  'where',
#  'whereafter',
#  'whereas',
#  'whereby',
#  'wherein',
#  'whereupon',
#  'wherever',
#  'whether',
#  'which',
#  'while',
#  'whither',
#  'who',
#  'whoever',
#  'whole',
#  'whom',
#  'whose',
#  'why',
#  'will',
#  'with',
#  'within',
#  'without',
#  'would',
#  'yet',
#  'you',
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  '‘d',
#  '‘ll',
#  '‘m',
#  '‘re',
#  '‘s',
#  '‘ve',
#  '’d',
#  '’ll',
#  '’m',
#  '’re',
#  '’s',
#  '’ve'}

# %%
x = 'this is the text data'

# %%
x.split()
# Out:
# ['this', 'is', 'the', 'text', 'data']

# %%
[t for t in x.split() if t in stopwords]
# Out:
# ['this', 'is', 'the']

# %%
df['stop_words_len'] = df['twitts'].apply(lambda x : len([t for t in x.split() if t in stopwords]))

# %%
df
# Out:
#                                                  twitts  sentiment  \
# 0     is bored and wants to watch a movie  any sugge...          0
# 1              back in miami.  waiting to unboard ship           0
# 2     @misskpey awwww dnt dis brng bak memoriessss, ...          0
# 3                     ughhh i am so tired  blahhhhhhhhh          0
# 4     @mandagoforth me bad! It's funny though. Zacha...          0
# ...                                                 ...        ...
# 3995                                  i just graduated           1
# 3996          Templating works; it all has to be done            1
# 3997                   mommy just brought me starbucks           1
# 3998  @omarepps watching you on a House re-run...lov...          1
# 3999  Thanks for trying to make me smile I'll make y...          1
#
#       word_counts  char_counts  avg_word_length  stop_words_len
# 0              10           43         4.300000               5
# 1               7           32         4.571429               3
# 2              12           54         4.500000               0
# 3               6           27         4.500000               3
# 4              26          116         4.461538              13
# ...           ...          ...              ...             ...
# 3995            3           14         4.666667               2
# 3996            8           32         4.000000               6
# 3997            5           27         5.400000               2
# 3998            8           45         5.625000               3
# 3999           16           63         3.937500               9
#
# [4000 rows x 6 columns]

# %%
x = 'this is the text data'
[t for t in x.split() if t not in stopwords]
# Out:
# ['text', 'data']

# %%
df['without_stop_words'] = df['twitts'].apply(lambda x : ' '.join([t for t in x.split() if t not in stopwords]))

# %%
df
# Out:
#                                                  twitts  sentiment  \
# 0     is bored and wants to watch a movie  any sugge...          0
# 1              back in miami.  waiting to unboard ship           0
# 2     @misskpey awwww dnt dis brng bak memoriessss, ...          0
# 3                     ughhh i am so tired  blahhhhhhhhh          0
# 4     @mandagoforth me bad! It's funny though. Zacha...          0
# ...                                                 ...        ...
# 3995                                  i just graduated           1
# 3996          Templating works; it all has to be done            1
# 3997                   mommy just brought me starbucks           1
# 3998  @omarepps watching you on a House re-run...lov...          1
# 3999  Thanks for trying to make me smile I'll make y...          1
#
#       word_counts  char_counts  avg_word_length  stop_words_len  \
# 0              10           43         4.300000               5
# 1               7           32         4.571429               3
# 2              12           54         4.500000               0
# 3               6           27         4.500000               3
# 4              26          116         4.461538              13
# ...           ...          ...              ...             ...
# 3995            3           14         4.666667               2
# 3996            8           32         4.000000               6
# 3997            5           27         5.400000               2
# 3998            8           45         5.625000               3
# 3999           16           63         3.937500               9
#
#                                      without_stop_words
# 0                  bored wants watch movie suggestions?
# 1                           miami. waiting unboard ship
# 2     @misskpey awwww dnt dis brng bak memoriessss, ...
# 3                              ughhh tired blahhhhhhhhh
# 4     @mandagoforth bad! It's funny though. Zachary ...
# ...                                                 ...
# 3995                                          graduated
# 3996                                  Templating works;
# 3997                            mommy brought starbucks
# 3998        @omarepps watching House re-run...lovin it.
# 3999        Thanks trying smile I'll 18th special hope!
#
# [4000 rows x 7 columns]

# %% [markdown]
# # Count #HashTags and @Mentions

# %%
x = 'this is #hashtag and this @mention'

# %%
x.split()
# Out:
# ['this', 'is', '#hashtag', 'and', 'this', '@mention']

# %%
len([t for t in x.split() if t.startswith('@')])
# Out:
# 1

# %%
df.rename(columns = {'without_stop_words':'twitts_without_stop_words'},inplace = True)

# %%
df
# Out:
#                                                  twitts  sentiment  \
# 0     is bored and wants to watch a movie  any sugge...          0
# 1              back in miami.  waiting to unboard ship           0
# 2     @misskpey awwww dnt dis brng bak memoriessss, ...          0
# 3                     ughhh i am so tired  blahhhhhhhhh          0
# 4     @mandagoforth me bad! It's funny though. Zacha...          0
# ...                                                 ...        ...
# 3995                                  i just graduated           1
# 3996          Templating works; it all has to be done            1
# 3997                   mommy just brought me starbucks           1
# 3998  @omarepps watching you on a House re-run...lov...          1
# 3999  Thanks for trying to make me smile I'll make y...          1
#
#       word_counts  char_counts  avg_word_length  stop_words_len  \
# 0              10           43         4.300000               5
# 1               7           32         4.571429               3
# 2              12           54         4.500000               0
# 3               6           27         4.500000               3
# 4              26          116         4.461538              13
# ...           ...          ...              ...             ...
# 3995            3           14         4.666667               2
# 3996            8           32         4.000000               6
# 3997            5           27         5.400000               2
# 3998            8           45         5.625000               3
# 3999           16           63         3.937500               9
#
#                               twitts_without_stop_words
# 0                  bored wants watch movie suggestions?
# 1                           miami. waiting unboard ship
# 2     @misskpey awwww dnt dis brng bak memoriessss, ...
# 3                              ughhh tired blahhhhhhhhh
# 4     @mandagoforth bad! It's funny though. Zachary ...
# ...                                                 ...
# 3995                                          graduated
# 3996                                  Templating works;
# 3997                            mommy brought starbucks
# 3998        @omarepps watching House re-run...lovin it.
# 3999        Thanks trying smile I'll 18th special hope!
#
# [4000 rows x 7 columns]

# %%
x = 'this is #hashtag and this @mention'
[t for t in x.split() if((t.startswith('#')) or (t.startswith('@')))]
# Out:
# ['#hashtag', '@mention']

# %%
df['numeric_counts'] = df['twitts'].apply(lambda x : len([t for t in x.split() if t.isdigit()]))

# %%
df.sample(5)
# Out:
#                                                  twitts  sentiment  \
# 1007  @DarlingNickieB daaannnnggg you dont love me n...          0
# 2499  http://twitpic.com/69jrk - THE boot screen of ...          1
# 643   @gerard_k mr spence has left us waiting outsid...          0
# 3516  Hi KimKardashian pleasure to talk with ya  ya ...          1
# 596   @allimendiola i miss you sister! &lt;3 i eat t...          0
#
#       word_counts  char_counts  avg_word_length  stop_words_len  \
# 1007            8           47         5.875000               3
# 2499           16           86         5.375000               3
# 643            23          101         4.391304               8
# 3516           18           82         4.555556               4
# 596            27          109         4.037037              16
#
#                               twitts_without_stop_words  numeric_counts
# 1007       @DarlingNickieB daaannnnggg dont love more??               0
# 2499  http://twitpic.com/69jrk - THE boot screen Aou...               0
# 643   @gerard_k mr spence left waiting outside room ...               0
# 3516  Hi KimKardashian pleasure talk ya ya liked pro...               1
# 596   @allimendiola miss sister! &lt;3 eat young coc...               0

# %%
x = 'I AM HAPPY'
y = 'i am happy'

# %%
[t for t in x.split() if t.isupper()]
# Out:
# ['I', 'AM', 'HAPPY']

# %%
df['upper_case'] = df['twitts'].apply(lambda x: len([t for t in x.split() if t.isupper()]))

# %%
df.sample(5)
# Out:
#                                                  twitts  sentiment  \
# 743   What the deuce!?! I thought it was 11am! I can...          0
# 358   Thanks dentist. I love you. Great, great timin...          0
# 2827  @ramsey Are you sure you are from Georgia? I'm...          1
# 3064  Had fun with emily  hopefully seeing chris ton...          1
# 2374  #FollowFriday  Follow @LilHappyHeathen  'cause...          1
#
#       word_counts  char_counts  avg_word_length  stop_words_len  \
# 743            16           67         4.187500               5
# 358             8           43         5.375000               0
# 2827           14           61         4.357143               6
# 3064            8           42         5.250000               1
# 2374           12           67         5.583333               4
#
#                               twitts_without_stop_words  numeric_counts  \
# 743   What deuce!?! I thought 11am! I can't sleep an...               0
# 358   Thanks dentist. I love you. Great, great timin...               0
# 2827   @ramsey Are sure Georgia? I'm missing heat here.               0
# 3064       Had fun emily hopefully seeing chris tonight               0
# 2374  #FollowFriday Follow @LilHappyHeathen 'cause s...               0
#
#       upper_case
# 743            2
# 358            1
# 2827           0
# 3064           0
# 2374           1

# %%
df.loc[2702]
# Out:
# twitts                       Today I performed for the first and last time ...
# sentiment                                                                    1
# word_counts                                                                 21
# char_counts                                                                 89
# avg_word_length                                                       4.238095
# stop_words_len                                                              10
# twitts_without_stop_words    Today I performed time Grebel talent show. 4 e...
# numeric_counts                                                               1
# upper_case                                                                   1
# Name: 2702, dtype: object

# %% [markdown]
# <h1>Preprocessing and Cleaning</h1>
# <h3>Lower Case Conversion</h3>

# %%
df['twitts'] = df['twitts'].apply(lambda x: str(x).lower())

# %%
df.sample(5)
# Out:
#                                                  twitts  sentiment  \
# 3029  @jonasgirly1209 yeah i love that song too  and...          1
# 2229  @tamarahland i'm not looking for internship - ...          1
# 3202  i can't wait to see the new moon trailer tomor...          1
# 2528                       i want another kan  @t_paine          1
# 1470  @acowboyswife that is *so* not begging!  if i ...          0
#
#       word_counts  char_counts  avg_word_length  stop_words_len  \
# 3029           18           73         4.055556               9
# 2229           21          113         5.380952               7
# 3202           13           56         4.307692               3
# 2528            5           23         4.600000               1
# 1470           26          106         4.076923              13
#
#                               twitts_without_stop_words  numeric_counts  \
# 3029  @Jonasgirly1209 yeah love song nope yet, i'd l...               0
# 2229  @TamarahLand I'm looking internship - I'm look...               0
# 3202  I can't wait NEW MOON trailer tomorrow! OMG SO...               0
# 2528                                I want kan @t_paine               0
# 1470  @acowboyswife *so* begging! If I credit I tota...               0
#
#       upper_case
# 3029           0
# 2229           0
# 3202           6
# 2528           1
# 1470           2

# %% [markdown]
# # Contraction to Expansion

# %%
contractions = {
"ain't": "am not",
"aren't": "are not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he would",
"he'd've": "he would have",
"he'll": "he will",
"he'll've": "he will have",
"he's": "he is",
"how'd": "how did",
"how'd'y": "how do you",
"how'll": "how will",
"how's": "how does",
"i'd": "i would",
"i'd've": "i would have",
"i'll": "i will",
"i'll've": "i will have",
"i'm": "i am",
"i've": "i have",
"isn't": "is not",
"it'd": "it would",
"it'd've": "it would have",
"it'll": "it will",
"it'll've": "it will have",
"it's": "it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"mightn't've": "might not have",
"must've": "must have",
"mustn't": "must not",
"mustn't've": "must not have",
"needn't": "need not",
"needn't've": "need not have",
"o'clock": "of the clock",
"oughtn't": "ought not",
"oughtn't've": "ought not have",
"shan't": "shall not",
"sha'n't": "shall not",
"shan't've": "shall not have",
"she'd": "she would",
"she'd've": "she would have",
"she'll": "she will",
"she'll've": "she will have",
"she's": "she is",
"should've": "should have",
"shouldn't": "should not",
"shouldn't've": "should not have",
"so've": "so have",
"so's": "so is",
"that'd": "that would",
"that'd've": "that would have",
"that's": "that is",
"there'd": "there would",
"there'd've": "there would have",
"there's": "there is",
"they'd": "they would",
"they'd've": "they would have",
"they'll": "they will",
"they'll've": "they will have",
"they're": "they are",
"they've": "they have",
"to've": "to have",
"wasn't": "was not",
" u ": " you ",
" ur ": " your ",
" n ": " and ",
"won't": "would not",
'dis': 'this',
'bak': 'back',
'brng': 'bring',
"won't":"would not",
'dis':'this',
"bak":"back",
"brng":'bring'
}

# %%
def cont_to_exp(x):
  if type(x) is str:
    for key in contractions:
      value = contractions[key]
      x = x.replace(key, value)
    return x
  else:
    return x

# %%
x = "i'm don't he'll"
cont_to_exp(x)
# Out:
# 'i am do not he will'

# %%
# %%timeit
df['twitts'] = df['twitts'].apply(lambda x: cont_to_exp(x))
# Out:
# 92.7 ms ± 24.9 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
df.sample(5)
# Out:
#                                                  twitts  sentiment  \
# 1338  i am burnt on only one side of my body  why di...          0
# 2395    @aplusk where did you get that? it sounds good           1
# 687           @reamer77 it is never long enough though           0
# 2740  http://twitpic.com/61dcj -  okay i cheated a l...          1
# 1119  aw no izzy from greys is dieing. she is one of...          0
#
#       word_counts  char_counts  avg_word_length  stop_words_len  \
# 1338           14           44         3.142857               8
# 2395            9           38         4.222222               5
# 687             6           34         5.666667               3
# 2740           14           72         5.142857               5
# 1119           23          101         4.391304              10
#
#                               twitts_without_stop_words  numeric_counts  \
# 1338                        I burnt body didn't I flip?               0
# 2395                          @aplusk that? sounds good               0
# 687                                 @reamer77 it's long               0
# 2740  http://twitpic.com/61dcj - okay cheated lil bi...               0
# 1119  Aw izzy greys dieing. She's fav characters hop...               0
#
#       upper_case
# 1338           2
# 2395           0
# 687            0
# 2740           0
# 1119           0

# %% [markdown]
# # Count and Remove Emails

# %%
import re

# %%
 df[df['twitts'].str.contains('hotmail.com')]
# Out:
#                                                  twitts  sentiment  \
# 3713  @securerecs arghh me please  markbradbury_16@h...          1
#
#       word_counts  char_counts  avg_word_length  stop_words_len  \
# 3713            5           51             10.2               0
#
#                               twitts_without_stop_words  numeric_counts  \
# 3713  @securerecs arghh Me Please markbradbury_16@ho...               0
#
#       upper_case
# 3713           0

# %%
df.iloc[3713]['twitts']
# Out:
# '@securerecs arghh me please  markbradbury_16@hotmail.com'

# %%
x = '@securerecs arghh me please  markbradbury_16@hotmail.com'

# %%
re.findall(r'([a-z0-9+._-]+@[a-z0-9+._-]+\.[a-z0-9+_-]+)',x)
# Out:
# ['markbradbury_16@hotmail.com']

# %%
df['emails'] = df['twitts'].apply(lambda x: re.findall(r'([a-z0-9+._-]+@[a-z0-9+._-]+\.[a-z0-9+_-]+)',x) )

# %%
df
# Out:
#                                                  twitts  sentiment  \
# 0     is bored and wants to watch a movie  any sugge...          0
# 1              back in miami.  waiting to unboard ship           0
# 2     @misskpey awwww dnt this bring back memoriesss...          0
# 3                     ughhh i am so tired  blahhhhhhhhh          0
# 4     @mandagoforth me bad! it is funny though. zach...          0
# ...                                                 ...        ...
# 3995                                  i just graduated           1
# 3996          templating works; it all has to be done            1
# 3997                   mommy just brought me starbucks           1
# 3998  @omarepps watching you on a house re-run...lov...          1
# 3999  thanks for trying to make me smile i will make...          1
#
#       word_counts  char_counts  avg_word_length  stop_words_len  \
# 0              10           43         4.300000               5
# 1               7           32         4.571429               3
# 2              12           54         4.500000               0
# 3               6           27         4.500000               3
# 4              26          116         4.461538              13
# ...           ...          ...              ...             ...
# 3995            3           14         4.666667               2
# 3996            8           32         4.000000               6
# 3997            5           27         5.400000               2
# 3998            8           45         5.625000               3
# 3999           16           63         3.937500               9
#
#                               twitts_without_stop_words  numeric_counts  \
# 0                  bored wants watch movie suggestions?               0
# 1                           miami. waiting unboard ship               0
# 2     @misskpey awwww dnt dis brng bak memoriessss, ...               0
# 3                              ughhh tired blahhhhhhhhh               0
# 4     @mandagoforth bad! It's funny though. Zachary ...               0
# ...                                                 ...             ...
# 3995                                          graduated               0
# 3996                                  Templating works;               0
# 3997                            mommy brought starbucks               0
# 3998        @omarepps watching House re-run...lovin it.               0
# 3999        Thanks trying smile I'll 18th special hope!               0
#
#       upper_case emails
# 0              0     []
# 1              0     []
# 2              1     []
# 3              0     []
# 4              0     []
# ...          ...    ...
# 3995           0     []
# 3996           0     []
# 3997           0     []
# 3998           0     []
# 3999           0     []
#
# [4000 rows x 10 columns]

# %%
df['emails_counts'] = df['emails'].apply(lambda x: len(x))

# %%
df[df['emails_counts']>0]
# Out:
#                                                  twitts  sentiment  \
# 3713  @securerecs arghh me please  markbradbury_16@h...          1
#
#       word_counts  char_counts  avg_word_length  stop_words_len  \
# 3713            5           51             10.2               0
#
#                               twitts_without_stop_words  numeric_counts  \
# 3713  @securerecs arghh Me Please markbradbury_16@ho...               0
#
#       upper_case                         emails  emails_counts
# 3713           0  [markbradbury_16@hotmail.com]              1

# %%
re.sub(r'([a-z0-9+._-]+@[a-z0-9+._-]+\.[a-z0-9+_-]+)'," ",x)
# Out:
# '@securerecs arghh me please   '

# %%
df['twitts'] = df['twitts'].apply(lambda x: re.sub(r'([a-z0-9+._-]+@[a-z0-9+._-]+\.[a-z0-9+_-]+)'," ",x))

# %% [markdown]
# # Count URLs and Remove it

# %%
x = 'hi, thanks to watching it. for more visit https://youtube.com/kgptalikie'

# %%
re.findall(r'(http|https|ftp|ssh)://([\w_-]+(?:(?:\.[\w_-]+)+))([\w.,@?^=%&:/~+#-]*[\w@?^=%&/~+#-])?',x)
# Out:
# [('https', 'youtube.com', '/kgptalikie')]

# %%
df['url_flags'] = df['twitts'].apply(lambda x: len(re.findall(r'(http|https|ftp|ssh)://([\w_-]+(?:(?:\.[\w_-]+)+))([\w.,@?^=%&:/~+#-]*[\w@?^=%&/~+#-])?',x)))

# %%
df[df['url_flags']>0]
# Out:
#                                                  twitts  sentiment  \
# 16    @brianquest i made 1 fo you 2: http://bit.ly/e...          0
# 98            heading to work  http://twitpic.com/4eojz          0
# 99    @blondeblogger http://twitpic.com/4w8hk - i am...          0
# 144            i miss you  ã¢ââ« http://blip.fm/~8lc2f          0
# 183    photo: miss germany  http://tumblr.com/xf825f012          0
# ...                                                 ...        ...
# 3819  new staark video of &quot;sweet release&quot; ...          1
# 3826  http://tinyurl.com/kwmynq helmet - unsung to s...          1
# 3837  @r0ckergirl14 wow sweet again!!  http://twitpi...          1
# 3958  someone has been creative with my #deskmess wh...          1
# 3974  @gtucker13 http://twitpic.com/6tw87 - no reall...          1
#
#       word_counts  char_counts  avg_word_length  stop_words_len  \
# 16             19           81         4.263158               3
# 98              4           37         9.250000               1
# 99             10           62         6.200000               4
# 144             5           35         7.000000               1
# 183             4           44        11.000000               0
# ...           ...          ...              ...             ...
# 3819           20          118         5.900000               4
# 3826            9           76         8.444444               2
# 3837            5           52        10.400000               0
# 3958           13           91         7.000000               7
# 3974           16           84         5.250000               9
#
#                               twitts_without_stop_words  numeric_counts  \
# 16    @BrianQuest I 1 fo u 2: http://bit.ly/eId8A I ...               1
# 98                Heading work http://twitpic.com/4eojz               0
# 99    @BlondeBlogger http://twitpic.com/4w8hk - I'm ...               0
# 144                 I miss Ã¢ÂÂ« http://blip.fm/~8lc2f               0
# 183     Photo: miss germany http://tumblr.com/xf825f012               0
# ...                                                 ...             ...
# 3819  NEW staark video &quot;Sweet Release&quot; liv...               0
# 3826  http://tinyurl.com/kwmynq Helmet - Unsung star...               0
# 3837  @r0ckergirl14 wow sweet again!! http://twitpic...               0
# 3958  Someone creative #deskmess chatting @omar_musa...               0
# 3974  @gtucker13 http://twitpic.com/6tw87 - .. germa...               0
#
#       upper_case emails  emails_counts  url_flags
# 16             3     []              0          1
# 98             0     []              0          1
# 99             0     []              0          1
# 144            2     []              0          1
# 183            0     []              0          1
# ...          ...    ...            ...        ...
# 3819           1     []              0          1
# 3826           0     []              0          2
# 3837           0     []              0          1
# 3958           0     []              0          1
# 3974           0     []              0          1
#
# [185 rows x 12 columns]

# %%
re.sub(r'(http|https|ftp|ssh)://([\w_-]+(?:(?:\.[\w_-]+)+))([\w.,@?^=%&:/~+#-]*[\w@?^=%&/~+#-])?'," ",x)
# Out:
# 'hi, thanks to watching it. for more visit  '

# %%
df['twitts'] = df['twitts'].apply(lambda x: re.sub(r'(http|https|ftp|ssh)://([\w_-]+(?:(?:\.[\w_-]+)+))([\w.,@?^=%&:/~+#-]*[\w@?^=%&/~+#-])?'," ",x) )

# %%
df.iloc[16]
# Out:
# twitts                       @brianquest i made 1 fo you 2:    i tried but ...
# sentiment                                                                    0
# word_counts                                                                 19
# char_counts                                                                 81
# avg_word_length                                                       4.263158
# stop_words_len                                                               3
# twitts_without_stop_words    @BrianQuest I 1 fo u 2: http://bit.ly/eId8A I ...
# numeric_counts                                                               1
# upper_case                                                                   3
# emails                                                                      []
# emails_counts                                                                0
# url_flags                                                                    1
# Name: 16, dtype: object

# %% [markdown]
# # Remove RT

# %%
df[df['twitts'].str.contains('rt ')]
# Out:
#                                                  twitts  sentiment  \
# 59    @paulmccourt dunno what sky you're looking at!...          0
# 106   doing art while watching season 6 of family gu...          0
# 114   @jsong77  not done it is almost 2 am  this you...          0
# 152   @bagginsboy best part is i have got t4 to watc...          0
# 178   watching jonas brothers on mtv, missed the 3d ...          0
# ...                                                 ...        ...
# 3826               helmet - unsung to start your day             1
# 3877  nat and jade are walking gus. this means i hav...          1
# 3907  the best part about having alzheimers: plannin...          1
# 3913  for the press so after she recovered she kille...          1
# 3945  @teciav &quot;i look high, i look low, i look ...          1
#
#       word_counts  char_counts  avg_word_length  stop_words_len  \
# 59             15           80         5.333333               3
# 106            15           59         3.933333               8
# 114            13           62         4.769231               1
# 152            11           49         4.454545               4
# 178            11           50         4.545455               3
# ...           ...          ...              ...             ...
# 3826            9           76         8.444444               2
# 3877           26          107         4.115385               8
# 3907           11           60         5.454545               4
# 3913           24          100         4.166667               1
# 3945           23          106         4.608696              10
#
#                               twitts_without_stop_words  numeric_counts  \
# 59    @paulmccourt dunno sky you're looking at! load...               0
# 106               art watching season 6 family guy! sun               1
# 114   @jsong77 NOT DONE IT'S ALMOST 2 AM youtbe bett...               1
# 152          @bagginsboy best i've got t4 watch tonight               0
# 178   Watching jonas brothers MTV, missed 3d concert...               0
# ...                                                 ...             ...
# 3826  http://tinyurl.com/kwmynq Helmet - Unsung star...               0
# 3877  Nat jade walking gus. This means I control tv....               0
# 3907  best having alzheimers: planning ur surprise p...               0
# 3913  For The Press So After She Recovered She Kille...               0
# 3945  @teciav &quot;i look high, look low, look go.....               0
#
#       upper_case emails  emails_counts  url_flags
# 59             0     []              0          0
# 106            0     []              0          0
# 114            5     []              0          0
# 152            0     []              0          0
# 178            2     []              0          0
# ...          ...    ...            ...        ...
# 3826           0     []              0          2
# 3877           1     []              0          0
# 3907           0     []              0          0
# 3913           0     []              0          0
# 3945           0     []              0          0
#
# [120 rows x 12 columns]

# %%
x = 'rt @username: hello hi'

# %%
re.sub(r'\brt\b', '',x).strip()
# Out:
# '@username: hello hi'

# %%
df['twitts'] = df['twitts'].apply(lambda x: re.sub(r'\brt\b', '',x).strip())

# %% [markdown]
# # Special Chars removal or puncuation removal

# %%
x = ' @brianquest i made 1 fo you 2:    i tried but ...'

# %%
re.sub(r'[^\w ]+',"",x)
# Out:
# ' brianquest i made 1 fo you 2    i tried but '

# %%
df['twitts'] = df['twitts'].apply(lambda x : re.sub(r'[^\w ]+',"",x))

# %%
df.head()
# Out:
#                                               twitts  sentiment  word_counts  \
# 0  is bored and wants to watch a movie  any sugge...          0           10
# 1             back in miami  waiting to unboard ship          0            7
# 2  misskpey awwww dnt this bring back memoriessss...          0           12
# 3                  ughhh i am so tired  blahhhhhhhhh          0            6
# 4  mandagoforth me bad it is funny though zachary...          0           26
#
#    char_counts  avg_word_length  stop_words_len  \
# 0           43         4.300000               5
# 1           32         4.571429               3
# 2           54         4.500000               0
# 3           27         4.500000               3
# 4          116         4.461538              13
#
#                            twitts_without_stop_words  numeric_counts  \
# 0               bored wants watch movie suggestions?               0
# 1                        miami. waiting unboard ship               0
# 2  @misskpey awwww dnt dis brng bak memoriessss, ...               0
# 3                           ughhh tired blahhhhhhhhh               0
# 4  @mandagoforth bad! It's funny though. Zachary ...               0
#
#    upper_case emails  emails_counts  url_flags
# 0           0     []              0          0
# 1           0     []              0          0
# 2           1     []              0          0
# 3           0     []              0          0
# 4           0     []              0          0

# %% [markdown]
# # Remove multiple spaces

# %%
x = 'hi    hello     how are you'

# %%
' '.join(x.split())
# Out:
# 'hi hello how are you'

# %%
df['twitts'] = df['twitts'].apply(lambda x: ' '.join(x.split()))

# %% [markdown]
# # Remove HTML tags

# %%
from bs4 import BeautifulSoup

# %%
x = '<html><h1> thanks for watching it</h1></html>'

# %%
x.replace('<html><h1>','')
# Out:
# ' thanks for watching it</h1></html>'

# %%
BeautifulSoup(x,'lxml').get_text().strip()
# Out:
# 'thanks for watching it'

# %%
# %%time
df['twitts'] = df['twitts'].apply(lambda x : BeautifulSoup(x,'lxml').get_text().strip())
# Out:
# CPU times: user 1.04 s, sys: 26.8 ms, total: 1.06 s
# Wall time: 1.07 s

# %%
df.head()
# Out:
#                                               twitts  sentiment  word_counts  \
# 0  is bored and wants to watch a movie any sugges...          0           10
# 1              back in miami waiting to unboard ship          0            7
# 2  misskpey awwww dnt this bring back memoriessss...          0           12
# 3                   ughhh i am so tired blahhhhhhhhh          0            6
# 4  mandagoforth me bad it is funny though zachary...          0           26
#
#    char_counts  avg_word_length  stop_words_len  \
# 0           43         4.300000               5
# 1           32         4.571429               3
# 2           54         4.500000               0
# 3           27         4.500000               3
# 4          116         4.461538              13
#
#                            twitts_without_stop_words  numeric_counts  \
# 0               bored wants watch movie suggestions?               0
# 1                        miami. waiting unboard ship               0
# 2  @misskpey awwww dnt dis brng bak memoriessss, ...               0
# 3                           ughhh tired blahhhhhhhhh               0
# 4  @mandagoforth bad! It's funny though. Zachary ...               0
#
#    upper_case emails  emails_counts  url_flags
# 0           0     []              0          0
# 1           0     []              0          0
# 2           1     []              0          0
# 3           0     []              0          0
# 4           0     []              0          0

# %% [markdown]
# # Remove Accented Chars

# %%
x = 'Áccěntěd těxt'

# %%
import unicodedata

# %%
def remove_accented_chars(x):
  x = unicodedata.normalize('NFKD',x).encode('ascii','ignore').decode('utf-8','ignore')
  return x

# %%
remove_accented_chars(x)
# Out:
# 'Accented text'

# %%
df['twitts'] = df['twitts'].apply(lambda x : remove_accented_chars(x))

# %% [markdown]
# # Remove Stop Words

# %%
df['twitts'] = df['twitts'].apply(lambda x : ' '.join([t for t in x.split() if t not in stopwords]))

# %%
df.head()
# Out:
#                                               twitts  sentiment  word_counts  \
# 0                bored wants watch movie suggestions          0           10
# 1                         miami waiting unboard ship          0            7
# 2  misskpey awwww dnt bring memoriessss thnk sad lol          0           12
# 3                           ughhh tired blahhhhhhhhh          0            6
# 4  mandagoforth bad funny zachary quinto amp repl...          0           26
#
#    char_counts  avg_word_length  stop_words_len  \
# 0           43         4.300000               5
# 1           32         4.571429               3
# 2           54         4.500000               0
# 3           27         4.500000               3
# 4          116         4.461538              13
#
#                            twitts_without_stop_words  numeric_counts  \
# 0               bored wants watch movie suggestions?               0
# 1                        miami. waiting unboard ship               0
# 2  @misskpey awwww dnt dis brng bak memoriessss, ...               0
# 3                           ughhh tired blahhhhhhhhh               0
# 4  @mandagoforth bad! It's funny though. Zachary ...               0
#
#    upper_case emails  emails_counts  url_flags
# 0           0     []              0          0
# 1           0     []              0          0
# 2           1     []              0          0
# 3           0     []              0          0
# 4           0     []              0          0

# %% [markdown]
# # Convert into base or root form of word

# %%
nlp = spacy.load('en_core_web_sm')

# %%
x = 'this is chocolates. what is times? this balls'

# %%
def make_to_base(x):
  x = str(x)
  x_list = []
  doc = nlp(x)
  for token in doc:
    lemma = token.lemma_
    if lemma == '-PRON-' or lemma == 'be':
      lemma = token.text
    x_list.append(lemma)
  return ' '.join(x_list)

# %%
make_to_base(x)
# Out:
# 'this is chocolate . what is time ? this ball'

# %%
df['twitts'] = df['twitts'].apply(lambda x: make_to_base(x))

# %%
df.sample(5)
# Out:
#                                                  twitts  sentiment  \
# 1111  cousin like brother sister today I m go visit ...          0
# 1773  missrios86 i m sorry do not kno marry do not w...          0
# 885   michellebyrne_x coolio guess shell aww go miss...          0
# 704                            x_imanerd_x can not face          0
# 648            kid asleep pacing floorboard koreatownla          0
#
#       word_counts  char_counts  avg_word_length  stop_words_len  \
# 1111           22           89         4.045455               8
# 1773           22           81         3.681818              11
# 885            14           63         4.500000               4
# 704             9           57         6.333333               4
# 648            13           85         6.538462               4
#
#                               twitts_without_stop_words  numeric_counts  \
# 1111  My cousins like brothers sisters today im goin...               0
# 1773  @MissRios86 im sorry didnt kno married, dont w...               0
# 885   @michellebyrne_x coolio guess shell aww i'm go...               0
# 704   @x_imANerd_x http://twitpic.com/7y752 - cant face               0
# 648   Kids asleep... I pacing floorboards. @ Koreato...               0
#
#       upper_case emails  emails_counts  url_flags
# 1111           0     []              0          0
# 1773           0     []              0          0
# 885            0     []              0          0
# 704            0     []              0          1
# 648            2     []              0          1

# %% [markdown]
# # Common words removal

# %%
x = 'this is this okay bye'

# %%
text = ' '.join(df['twitts'])

# %%
len(text)
# Out:
# 173192

# %%
text = text.split()

# %%
len(text)
# Out:
# 27801

# %%
freq_comm = pd.Series(text).value_counts()

# %%
freq_comm
# Out:
# day           265
# go            261
# good          232
# get           228
# work          201
#              ...
# majatutaja      1
# sablevenus      1
# swiss           1
# 4ish            1
# rerunlovin      1
# Length: 9013, dtype: int64

# %%
f20 = freq_comm[:20]

# %%
f20
# Out:
# day      265
# go       261
# good     232
# get      228
# work     201
# love     199
# like     197
# today    182
# not      165
# time     150
# think    149
# lol      149
# miss     143
# want     142
# know     140
# thank    137
# m        136
# amp      125
# look     118
# I        118
# dtype: int64

# %%
df['twitts'] = df['twitts'].apply(lambda x: ' '.join([t for t in x.split() if t not in f20]))

# %%
df.sample(5)
# Out:
#                                                  twitts  sentiment  \
# 3744  turn early high pain increase pain meds moreee...          1
# 1947      shontane haha oh pretty stilllllll sampe shit          0
# 3070                              psychic09 oh ok worry          1
# 3807                               chloevictoriaxo nice          1
# 1804                 wth freezing usually feel cold sun          0
#
#       word_counts  char_counts  avg_word_length  stop_words_len  \
# 3744           23          110         4.782609               7
# 1947           13           65         5.000000               4
# 3070           13           58         4.461538               6
# 3807            4           45        11.250000               0
# 1804           15           55         3.666667               4
#
#                               twitts_without_stop_words  numeric_counts  \
# 3744  Turning early. My high gone, pain increased, s...               0
# 1947  @shontane haha oh pretty! stilllllll going s&a...               0
# 3070      @Psychic09 Oh ok, don't worry can't anything.               0
# 3807   @chloevictoriaxo http://twitpic.com/5oo0f - nice               0
# 1804  Wth I freezing, I usually feel cold!! I miss s...               0
#
#       upper_case emails  emails_counts  url_flags
# 3744           2     []              0          0
# 1947           0     []              0          0
# 3070           0     []              0          0
# 3807           0     []              0          1
# 1804           3     []              0          0

# %% [markdown]
# # Rare words removal

# %%
rare20 = freq_comm.tail(20)

# %%
df['twitts'] = df['twitts'].apply(lambda x: ' '.join([t for t in x.split() if t not in rare20]))

# %%
df.sample(5)
# Out:
#                                                  twitts  sentiment  \
# 49        sonjacassella help brother parent morning way          0
# 367   karenplusone realize wl play couple show londo...          0
# 872               dang loop lateagain sadshopping lunch          0
# 3063  joshblaylock i woote tedious officeye review gosh          1
# 1554  3rd phone ato rudd bonus 1st lose mail 2nd los...          0
#
#       word_counts  char_counts  avg_word_length  stop_words_len  \
# 49             18           95         5.277778               6
# 367            24          110         4.583333               6
# 872            14           76         5.428571               5
# 3063           13           74         5.692308               5
# 1554           27          105         3.888889              10
#
#                               twitts_without_stop_words  numeric_counts  \
# 49    @SonjaCassella Not yet. Getting help brother &...               0
# 367   @karenplusone I realized WL playing couple sho...               0
# 872   dang it!!! how'd looped working late..AGAIN? s...               0
# 3063  @joshblaylock no, im woot-ing tedious office.....               0
# 1554  3rd phone ATO.... Rudd bonus 1st time lost mai...               1
#
#       upper_case emails  emails_counts  url_flags
# 49             0     []              0          0
# 367            2     []              0          0
# 872            0     []              0          0
# 3063           1     []              0          0
# 1554           2     []              0          0

# %%
#!pip install wordcloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
text = ' '.join(df['twitts'])

# %%
len(text)
# Out:
# 157607

# %%
wc = WordCloud(width=800, height=400).generate(text)
plt.imshow(wc)
plt.axis('off')
plt.show()

# %% [markdown]
# # Spelling Correction

# %%
#!pip install -U textblob

# %%
#!python -m textblob.download_corpora

# %%
from textblob import TextBlob

# %%
x = 'thankks forr waching it'

# %%
x = TextBlob(x).correct()

# %%
print(x)
# Out:
# thanks for watching it

# %% [markdown]
# # Tokenization using TextBlob

# %%
x = 'thanks#watching this video. please like it'

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
TextBlob(x).words
# Out:
# WordList(['thanks', 'watching', 'this', 'video', 'please', 'like', 'it'])

# %%
doc = nlp(x)
for token in doc:
  print(token)
# Out:
# thanks#watching
# this
# video
# .
# please
# like
# it

# %% [markdown]
# # Noun Detection

# %%
x = 'Breaking News: Donal Trump, the president of the USA is looking to sign a deal to mine the moon'

# %%
doc = nlp(x)
for noun in doc.noun_chunks:
    print(noun)
# Out:
# Donal Trump
# the president
# the USA
# a deal
# the moon

# %% [markdown]
# # Language Translation and detection
# Language Code: https://www.loc.gov/standards/iso639-2/php/code_list.php

# %%
x
# Out:
# 'Breaking News: Donal Trump, the president of the USA is looking to sign a deal to mine the moon'

# %%
tb = TextBlob(x)

# %%
tb.detect_language()

# %%
tb.translate(to='fr')

# %% [markdown]
# # Use TextBlob's Inbuilt Sentiment Classifier

# %%
from textblob.sentiments import NaiveBayesAnalyzer

# %%
x = 'we all stands together. we are gonna win this fight'

# %%
tb = TextBlob(x, analyzer = NaiveBayesAnalyzer())

# %%
nltk.download('movie_reviews')
# Out:
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Unzipping corpora/movie_reviews.zip.
# True
