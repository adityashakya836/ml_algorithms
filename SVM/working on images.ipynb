# %%
img_path = "C:\\Users\\Aditya Shakya\\OneDrive\\Desktop\\vrindavan\\IMG_20230303_190440_627.jpg"

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
img_reading = cv2.imread(img_path)

# %%
img_array = np.array(img_reading)

# %%
img = cv2.imwrite('temple.jpg',img_array)

# %%
print("# of dimensions",img_array.ndim)
print('Img shape ',img_array.shape)
print('Img dtype ',img_array.dtype)
print(img_array[20,20])
print(img_array[:,:,2].min())
# Out:
# # of dimensions 3
# Img shape  (1808, 4000, 3)
# Img dtype  uint8
# [22 20 12]
# 0

# %%
plt.imshow(img_array)
plt.axis("off")
plt.show()

# %%
transposed_img = img_array.flatten()

# %%
plt.hist(transposed_img, bins=200, range=[0, 256])
plt.title("Number of pixels in each intensity value")
plt.xlabel("Intensity")
plt.ylabel("Number of pixels")
plt.show()

# %%
img_bgr = cv2.cvtColor(img_array,cv2.COLOR_RGB2HLS)
plt.imshow(img_bgr)
plt.axis('off')
plt.show()
