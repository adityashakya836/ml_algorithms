# %% [markdown]
# ### import libraries for visulaazation and loading dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## crop producation dataset

# %%
crop = pd.read_csv('crop_production_data.csv')

# %%
crop
# Out:
#         District       Crop  Season  Area (hectares)  Yield (quintals)  \
# 0        Jodhpur      Wheat  Kharif      16490.14246         30.691986
# 1           Kota       Gram    Rabi      16943.06561         45.818232
# 2         Jaipur      Wheat    Rabi      14297.53988         29.752629
# 3    Hanumangarh  Coriander    Rabi      19737.63845         42.026511
# 4    Hanumangarh     Citrus    Rabi      13591.57684         38.195933
# ..           ...        ...     ...              ...               ...
# 995       Jaipur       Gram  Kharif      17401.22858         37.971750
# 996  Hanumangarh     Garlic    Rabi      18566.74011         48.880964
# 997       Nagaur  Coriander  Kharif      16054.34462         52.309529
# 998  Hanumangarh      Bajra  Kharif      14920.43622         44.458956
# 999      Udaipur     Barley    Rabi      14510.79911         42.673344
#
#      Production (metric tons)
# 0                 5061.152230
# 1                 7763.013072
# ...

# %%
crop.head()
# Out:
#       District       Crop  Season  Area (hectares)  Yield (quintals)  \
# 0      Jodhpur      Wheat  Kharif      16490.14246         30.691986
# 1         Kota       Gram    Rabi      16943.06561         45.818232
# 2       Jaipur      Wheat    Rabi      14297.53988         29.752629
# 3  Hanumangarh  Coriander    Rabi      19737.63845         42.026511
# 4  Hanumangarh     Citrus    Rabi      13591.57684         38.195933
#
#    Production (metric tons)
# 0               5061.152230
# 1               7763.013072
# 2               4253.893981
# 3               8295.040749
# 4               5191.429648

# %%
crop.tail()
# Out:
#         District       Crop  Season  Area (hectares)  Yield (quintals)  \
# 995       Jaipur       Gram  Kharif      17401.22858         37.971750
# 996  Hanumangarh     Garlic    Rabi      18566.74011         48.880964
# 997       Nagaur  Coriander  Kharif      16054.34462         52.309529
# 998  Hanumangarh      Bajra  Kharif      14920.43622         44.458956
# 999      Udaipur     Barley    Rabi      14510.79911         42.673344
#
#      Production (metric tons)
# 995               6607.551098
# 996               9075.601636
# 997               8397.952063
# 998               6633.470231
# 999               6192.243169

# %%
crop.shape
# Out:
# (1000, 6)

# %% [markdown]
# crop.info()

# %%
crop.describe()
# Out:
#        Area (hectares)  Yield (quintals)  Production (metric tons)
# count      1000.000000       1000.000000               1000.000000
# mean      15046.881839         37.618328               5662.518485
# std        2775.359803          8.218587               1629.922505
# min        5276.197980         20.272936               1728.445956
# 25%       13165.258125         31.105150               4438.671582
# 50%       15108.130415         37.227050               5561.468281
# 75%       16944.950090         43.711205               6769.771692
# max       20000.000000         60.429192              10834.530830

# %%
crop.isnull().sum()
# Out:
# District                    0
# Crop                        0
# Season                      0
# Area (hectares)             0
# Yield (quintals)            0
# Production (metric tons)    0
# dtype: int64

# %%
crop["Season"].unique
# Out:
# <bound method Series.unique of 0      Kharif
# 1        Rabi
# 2        Rabi
# 3        Rabi
# 4        Rabi
#         ...
# 995    Kharif
# 996      Rabi
# 997    Kharif
# 998    Kharif
# 999      Rabi
# Name: Season, Length: 1000, dtype: object>

# %%
crop ["Area (hectares)"].sum()
# Out:
# 15046881.838856999

# %%
crop_kharif=crop[crop["Season"]=="kharif"]

# %%
crop_Rabi=crop[crop["Season"]=="Rabi"]

# %%
crop_Rabi.head(4)
# Out:
#       District       Crop Season  Area (hectares)  Yield (quintals)  \
# 1         Kota       Gram   Rabi      16943.06561         45.818232
# 2       Jaipur      Wheat   Rabi      14297.53988         29.752629
# 3  Hanumangarh  Coriander   Rabi      19737.63845         42.026511
# 4  Hanumangarh     Citrus   Rabi      13591.57684         38.195933
#
#    Production (metric tons)
# 1               7763.013072
# 2               4253.893981
# 3               8295.040749
# 4               5191.429648

# %%
crop_kharif.head(4)
# Out:
# Empty DataFrame
# Columns: [District, Crop, Season, Area (hectares), Yield (quintals), Production (metric tons)]
# Index: []

# %%
plt.scatter(crop["Area (hectares)"],crop["Production (metric tons)"],c="g")
plt.xlabel("Area")
plt.ylabel("production")
# Out:
# Text(0, 0.5, 'production')

# %%
crop.head()
# Out:
#       District       Crop  Season  Area (hectares)  Yield (quintals)  \
# 0      Jodhpur      Wheat  Kharif      16490.14246         30.691986
# 1         Kota       Gram    Rabi      16943.06561         45.818232
# 2       Jaipur      Wheat    Rabi      14297.53988         29.752629
# 3  Hanumangarh  Coriander    Rabi      19737.63845         42.026511
# 4  Hanumangarh     Citrus    Rabi      13591.57684         38.195933
#
#    Production (metric tons)
# 0               5061.152230
# 1               7763.013072
# 2               4253.893981
# 3               8295.040749
# 4               5191.429648

# %%
plt.bar(crop["Season"],crop["Production (metric tons)"])
# Out:
# <BarContainer object of 1000 artists>

# %%
fig=plt.figure(figsize=(15,7))
plt.bar(crop["District"],crop["Production (metric tons)"])
# Out:
# <BarContainer object of 1000 artists>

# %%
crop_wheat=crop[crop["Crop"]=="Wheat"]

# %%
crop_wheat.head()
# Out:
#           District   Crop  Season  Area (hectares)  Yield (quintals)  \
# 0          Jodhpur  Wheat  Kharif      16490.14246         30.691986
# 2           Jaipur  Wheat    Rabi      14297.53988         29.752629
# 5   Sri Ganganagar  Wheat    Rabi      13609.74692         40.476300
# 36        Bhilwara  Wheat    Rabi      14892.52188         55.773345
# 57     Hanumangarh  Wheat    Rabi      14422.91711         49.611402
#
#     Production (metric tons)
# 0                5061.152230
# 2                4253.893981
# 5                5508.721962
# 36               8306.057636
# 57               7155.411340

# %%
crop_Citrus=crop[crop["Crop"]=="Citrus"]

# %%
crop_Citrus.head()
# Out:
#        District    Crop Season  Area (hectares)  Yield (quintals)  \
# 4   Hanumangarh  Citrus   Rabi      13591.57684         38.195933
# 41       Nagaur  Citrus   Rabi      19433.68213         45.723591
# 50     Bhilwara  Citrus   Rabi      10753.88777         26.207337
# 92         Kota  Citrus   Rabi      14329.61164         31.589177
# 93      Udaipur  Citrus   Rabi      16419.71287         31.439493
#
#     Production (metric tons)
# 4                5191.429648
# 41               8885.777390
# 50               2818.307646
# 92               4526.606361
# 93               5162.274403

# %%
plt.bar(["Wheat","Citrust"],[crop_wheat["Area (hectares)"].sum(),crop_Citrus["Area (hectares)"].sum()],)
# Out:
# <BarContainer object of 2 artists>

# %%
fig=plt.figure(figsize=(25,10))
plt.bar(crop["Crop"],crop["Production (metric tons)"])
# Out:
# <BarContainer object of 1000 artists>

# %%
fig=plt.figure(figsize=(25,10))
plt.scatter(crop["Yield (quintals)"],crop["Production (metric tons)"])

# %% [markdown]
# ## soil analysis dataset

# %%
Soil = pd.read_csv ("C:\\Users\\misha\\OneDrive\\Desktop\\soil_analysis_data.csv")

# %%
Soil
# Out:
#         District            Soil Type  pH Level  Organic Matter (%)  \
# 0         Jaipur  Chalky (Calcareous)  6.546096            1.569807
# 1       Bhilwara          Nitrogenous  6.832259            2.243018
# 2        Jodhpur                Sandy  7.453182            2.662898
# 3         Jaipur                 Clay  8.019189            1.240327
# 4         Jaipur                Sandy  8.100131            1.768419
# ..           ...                  ...       ...                 ...
# 995       Nagaur               Saline  7.660465            1.506067
# 996  Hanumangarh               Saline  7.035537            1.747936
# 997        Ajmer  Chalky (Calcareous)  7.079614            2.110315
# 998      Jodhpur          Nitrogenous  8.104615            1.987857
# 999       Jaipur          Nitrogenous  8.604928            2.163497
#
#      Nitrogen Content (kg/ha)  Phosphorus Content (kg/ha)  \
# 0                   27.931972                   29.438438
# ...

# %%
Soil .describe()
# Out:
#           pH Level  Organic Matter (%)  Nitrogen Content (kg/ha)  \
# count  1000.000000         1000.000000               1000.000000
# mean      7.495453            1.993592                 29.883358
# std       0.517155            0.515340                  5.202697
# min       5.889492            0.155817                 11.994574
# 25%       7.157881            1.638911                 26.217325
# 50%       7.500129            1.981462                 29.822797
# 75%       7.846940            2.345688                 33.232056
# max       9.038430            3.764528                 45.760284
#
#        Phosphorus Content (kg/ha)  Potassium Content (kg/ha)
# count                 1000.000000                1000.000000
# mean                    19.729932                  39.877907
# std                      5.067005                   4.874751
# min                      4.961838                  24.116481
# 25%                     16.216471                  36.703917
# ...

# %%
Soil_type = Soil["Soil Type"].value_counts()

# %%
Soil["Soil Type"].unique()
# Out:
# array(['Chalky (Calcareous)', 'Nitrogenous', 'Sandy', 'Clay',
#        'Black lava soil', 'Loamy', 'Saline', 'Alkaline'], dtype=object)

# %%
Soil["pH Level"].max()
# Out:
# 9.038430185090252

# %%
Soil["pH Level"].min()
# Out:
# 5.889491822007143

# %%
print(Soil_type)
# Out:
# Soil Type
# Black lava soil        144
# Saline                 135
# Clay                   130
# Alkaline               127
# Nitrogenous            123
# Sandy                  117
# Loamy                  117
# Chalky (Calcareous)    107
# Name: count, dtype: int64

# %%
Soil_type.plot.pie(autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### water usage dataset

# %%
water_usage = pd.read_csv("C:\\Users\\misha\\OneDrive\\Desktop\\water_usage_data.csv")

# %%
water_usage
# Out:
#            District      Crop     Irrigation Method  \
# 0           Udaipur    Garlic             Tube Well
# 1          Bhilwara      Gram       Drip Irrigation
# 2           Udaipur     Guava      Canal Irrigation
# 3           Jodhpur    Barley  Sprinkler Irrigation
# 4             Alwar      Gram      Canal Irrigation
# ..              ...       ...                   ...
# 995         Udaipur  Oilseeds  Sprinkler Irrigation
# 996         Jodhpur    Tomato  Sprinkler Irrigation
# 997            Kota     Bajra      Canal Irrigation
# 998        Bhilwara    Fennel       Drip Irrigation
# 999  Sri Ganganagar   Mustard             Tube Well
#
#      Water Consumption (liters/hectare)  Water Availability (liters/hectare)
# 0                          11609.330886                         11335.919980
# 1                          12648.406038                         12091.900254
# 2                          10063.162448                          9810.943169
# ...

# %%
water_usage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   District                             1000 non-null   object
#  1   Crop                                 1000 non-null   object
#  2   Irrigation Method                    1000 non-null   object
#  3   Water Consumption (liters/hectare)   1000 non-null   float64
#  4   Water Availability (liters/hectare)  1000 non-null   float64
# dtypes: float64(2), object(3)
# memory usage: 39.2+ KB

# %%
water_usage.describe()
# Out:
#        Water Consumption (liters/hectare)  Water Availability (liters/hectare)
# count                         1000.000000                          1000.000000
# mean                         10557.110759                         10543.621287
# std                           2835.083841                          2905.372578
# min                           4673.530139                          4505.257189
# 25%                           8238.226672                          8142.359044
# 50%                          10422.656935                         10524.479417
# 75%                          12808.359361                         12879.893934
# max                          18631.091327                         18489.171266

# %%
water_usage["Irrigation Method"].unique()
# Out:
# array(['Tube Well', 'Drip Irrigation', 'Canal Irrigation',
#        'Sprinkler Irrigation'], dtype=object)

# %%
water_usage["Water Availability (liters/hectare)"].max()
# Out:
# 18489.171266347672

# %%
water_usage["Water Consumption (liters/hectare)"].max()
# Out:
# 18631.09132663682

# %%
water_usage[water_usage["Water Availability (liters/hectare)"]==water_usage["Water Availability (liters/hectare)"].max()]
# Out:
#            District    Crop Irrigation Method  \
# 549  Sri Ganganagar  Fennel         Tube Well
#
#      Water Consumption (liters/hectare)  Water Availability (liters/hectare)
# 549                        17852.609677                         18489.171266

# %%
water_usage["Water Availability (liters/hectare)"].min()
# Out:
# 4505.257189045351

# %%
water_usage["Water Consumption (liters/hectare)"].min()
# Out:
# 4673.530139030418

# %%
water_usage[water_usage["Water Availability (liters/hectare)"]==water_usage["Water Availability (liters/hectare)"].min()]
# Out:
#     District         Crop     Irrigation Method  \
# 660    Alwar  Pomegranate  Sprinkler Irrigation
#
#      Water Consumption (liters/hectare)  Water Availability (liters/hectare)
# 660                            5459.317                          4505.257189

# %%
irri_method = water_usage['Irrigation Method'].value_counts()
print(irri_method)
# Out:
# Irrigation Method
# Sprinkler Irrigation    284
# Tube Well               252
# Drip Irrigation         243
# Canal Irrigation        221
# Name: count, dtype: int64

# %%
irri_method.plot.line()
# Out:
# <Axes: xlabel='Irrigation Method'>

# %%
water_type = water_usage["Irrigation Method"].value_counts()
print(water_type)
# Out:
# Irrigation Method
# Sprinkler Irrigation    284
# Tube Well               252
# Drip Irrigation         243
# Canal Irrigation        221
# Name: count, dtype: int64

# %%
water_type. plot.pie(autopct=('% .3f'))
plt.ylabel("")
plt.show()

# %%
water_usage["Irrigation Method"].min()
# Out:
# 'Canal Irrigation'

# %%
print(water_usage['Crop'].unique())
# Out:
# ['Garlic' 'Gram' 'Guava' 'Barley' 'Bajra' 'Pulses' 'Citrus' 'Opium'
#  'Fenugreek' 'Tomato' 'Sugarcane' 'Chilli' 'Onion' 'Pomegranate'
#  'Oilseeds' 'Maize' 'Cumin' 'Cotton' 'Mango' 'Coriander' 'Wheat' 'Mustard'
#  'Fennel']

# %%
total_water_crop = water_usage.groupby("Crop").mean().sort_values(by=("water Aailability(liters/hectare)"))
print(total_water_crop)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
# ...

# %% [markdown]
# ### crop price dataset

# %%
crop_price = pd.read_csv("C:\\Users\\misha\\OneDrive\\Desktop\\crop_price_data.csv")

# %%
crop_price
# Out:
#             District         Crop            Market        Date  \
# 0              Alwar       Barley  Alwar APMC Mandi  2018-09-05
# 1     Sri Ganganagar  Pomegranate    Padampur Mandi  2018-11-20
# 2               Kota        Maize     Ramganj Mandi  2018-04-06
# 3             Nagaur    Fenugreek     Didwana Mandi  2018-09-26
# 4             Nagaur         Gram     Didwana Mandi  2018-10-06
# ...              ...          ...               ...         ...
# 4814          Jaipur  Pomegranate       Bassi Mandi  2018-12-15
# 4815        Bhilwara        Mango      Mandal Mandi  2018-04-08
# 4816     Hanumangarh       Pulses   Pilibanga Mandi  2019-04-23
# 4817          Jaipur        Guava      Muhana Mandi  2018-07-24
# 4818           Alwar  Pomegranate      Tijara Mandi  2019-05-14
#
#       Price (INR/quintal)
# 0             2490.092421
# 1             2348.904922
# 2             2448.287513
# 3             2714.419518
# 4             2883.356997
# ...                   ...
# ...

# %%
crop_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4819 entries, 0 to 4818
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   District             4819 non-null   object
#  1   Crop                 4819 non-null   object
#  2   Market               4819 non-null   object
#  3   Date                 4819 non-null   object
#  4   Price (INR/quintal)  4819 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 188.4+ KB

# %%
crop_price.describe()
# Out:
#        Price (INR/quintal)
# count          4819.000000
# mean           2498.715360
# std             295.651094
# min            1323.279925
# 25%            2303.968087
# 50%            2497.697781
# 75%            2694.736166
# max            3513.330472

# %%
crop_price.head(4)

# %%
crop_price["Crop"].unique()
# Out:
# array(['Barley', 'Pomegranate', 'Maize', 'Fenugreek', 'Gram', 'Fennel',
#        'Pulses', 'Chilli', 'Onion', 'Tomato', 'Sugarcane', 'Cotton',
#        'Guava', 'Opium', 'Mustard', 'Cumin', 'Coriander', 'Oilseeds',
#        'Mango', 'Garlic', 'Bajra', 'Wheat', 'Citrus'], dtype=object)

# %%
fig = plt.figure(figsize = (22,5))
plt.bar(crop_price["Crop"],crop_price["Price (INR/quintal)"],color="orange")
plt.xlabel("Crop",fontsize=18)
plt.ylabel("Price",fontsize=18)
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# #Appyling linear regrission for forcasting

# %%
crop .info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   District                  1000 non-null   object
#  1   Crop                      1000 non-null   object
#  2   Season                    1000 non-null   object
#  3   Area (hectares)           1000 non-null   float64
#  4   Yield (quintals)          1000 non-null   float64
#  5   Production (metric tons)  1000 non-null   float64
# dtypes: float64(3), object(3)
# memory usage: 47.0+ KB

# %%
crop.describe()
# Out:
#        Area (hectares)  Yield (quintals)  Production (metric tons)
# count      1000.000000       1000.000000               1000.000000
# mean      15046.881839         37.618328               5662.518485
# std        2775.359803          8.218587               1629.922505
# min        5276.197980         20.272936               1728.445956
# 25%       13165.258125         31.105150               4438.671582
# 50%       15108.130415         37.227050               5561.468281
# 75%       16944.950090         43.711205               6769.771692
# max       20000.000000         60.429192              10834.530830

# %%
crop .head(5)
# Out:
#       District       Crop  Season  Area (hectares)  Yield (quintals)  \
# 0      Jodhpur      Wheat  Kharif      16490.14246         30.691986
# 1         Kota       Gram    Rabi      16943.06561         45.818232
# 2       Jaipur      Wheat    Rabi      14297.53988         29.752629
# 3  Hanumangarh  Coriander    Rabi      19737.63845         42.026511
# 4  Hanumangarh     Citrus    Rabi      13591.57684         38.195933
#
#    Production (metric tons)
# 0               5061.152230
# 1               7763.013072
# 2               4253.893981
# 3               8295.040749
# 4               5191.429648

# %%
from sklearn .preprocessing import LabelEncoder
LE=LabelEncoder

# %%
LE = LabelEncoder()

# %%
crop["District"] = LE.fit_transform(crop["District"])

# %%
crop["Crop"] = LE.fit_transform(crop["Crop"])

# %%
crop["Season"] = LE.fit_transform(crop["Season"])

# %%
crop.head(5)
# Out:
#    District  Crop  Season  Area (hectares)  Yield (quintals)  \
# 0         5    22       0      16490.14246         30.691986
# 1         6    10       1      16943.06561         45.818232
# 2         4    22       1      14297.53988         29.752629
# 3         3     4       1      19737.63845         42.026511
# 4         3     3       1      13591.57684         38.195933
#
#    Production (metric tons)
# 0               5061.152230
# 1               7763.013072
# 2               4253.893981
# 3               8295.040749
# 4               5191.429648

# %%
x = crop.iloc[:,:-1]

# %%
x.head()
# Out:
#    District  Crop  Season  Area (hectares)  Yield (quintals)
# 0         5    22       0      16490.14246         30.691986
# 1         6    10       1      16943.06561         45.818232
# 2         4    22       1      14297.53988         29.752629
# 3         3     4       1      19737.63845         42.026511
# 4         3     3       1      13591.57684         38.195933

# %%
y=crop.iloc[:,-1]

# %%
y.head()
# Out:
# 0    5061.152230
# 1    7763.013072
# 2    4253.893981
# 3    8295.040749
# 4    5191.429648
# Name: Production (metric tons), dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.2)

# %%
x_train.head()
# Out:
#      District  Crop  Season  Area (hectares)  Yield (quintals)
# 948         4    20       0      14223.61181         42.216939
# 235         6    16       1      14174.84491         21.674831
# 818         7     2       0      12134.63226         36.179824
# 704         7     7       0      14031.96048         28.418374
# 658         1     9       1      11804.65901         43.401592

# %%
x_test.head()
# Out:
#      District  Crop  Season  Area (hectares)  Yield (quintals)
# 126         2    21       0      20000.00000         48.316041
# 289         3     0       1      10564.24126         50.510541
# 291         7    22       0      16898.34560         57.009827
# 185         1    16       1      15073.53052         41.388914
# 634         1    21       0      12793.41017         30.991755

# %%
y_train.head()
# Out:
# 948    6004.773522
# 235    3072.373740
# 818    4390.288643
# 704    3987.654971
# 658    5123.409973
# Name: Production (metric tons), dtype: float64

# %%
y_test.head()
# Out:
# 126    9663.208271
# 289    5336.055438
# 291    9633.717584
# 185    6238.770512
# 634    3964.902379
# Name: Production (metric tons), dtype: float64

# %%
from sklearn.linear_model import LinearRegression
L_R=LinearRegression()

# %%
L_R.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
p=Lr.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_absolute_error,confusion_matrix

# %%
print(r2_score(p,y_test))
print(mean_absolute_error(p,y_test))
# Out:
# 0.981880268204983
# 149.0671296073621

# %%
# input by user
x_test[1:2]
# Out:
#      District  Crop  Season  Area (hectares)  Yield (quintals)
# 289         3     0       1      10564.24126         50.510541

# %% [raw]
# # original otput

# %%
y_test[1:2]
# Out:
# 289    5336.055438
# Name: Production (metric tons), dtype: float64

# %%
# predict output
L_R.predict(x_test[1:2])
# Out:
# array([5909.44950107])

# %% [markdown]
# ### EDA of Soil Data

# %%
soil_data = pd.read_csv('soil_analysis_data.csv')
water_data = pd.read_csv('water_usage_data.csv')

# %%
soil_data.head()
# Out:
#    District            Soil Type  pH Level  Organic Matter (%)  \
# 0    Jaipur  Chalky (Calcareous)  6.546096            1.569807
# 1  Bhilwara          Nitrogenous  6.832259            2.243018
# 2   Jodhpur                Sandy  7.453182            2.662898
# 3    Jaipur                 Clay  8.019189            1.240327
# 4    Jaipur                Sandy  8.100131            1.768419
#
#    Nitrogen Content (kg/ha)  Phosphorus Content (kg/ha)  \
# 0                 27.931972                   29.438438
# 1                 22.263480                   25.413455
# 2                 23.564182                   13.014409
# 3                 15.839222                   17.744206
# 4                 27.942867                   25.769504
#
#    Potassium Content (kg/ha)
# 0                  42.782766
# 1                  37.644377
# 2                  37.082003
# 3                  42.758704
# 4                  30.651292

# %%
soil_data.corr()
# Out:
#                             pH Level  Organic Matter (%)  \
# pH Level                    1.000000           -0.044368
# Organic Matter (%)         -0.044368            1.000000
# Nitrogen Content (kg/ha)   -0.000539           -0.056834
# Phosphorus Content (kg/ha)  0.018209            0.004745
# Potassium Content (kg/ha)  -0.021001           -0.001274
#
#                             Nitrogen Content (kg/ha)  \
# pH Level                                   -0.000539
# Organic Matter (%)                         -0.056834
# Nitrogen Content (kg/ha)                    1.000000
# Phosphorus Content (kg/ha)                  0.002912
# Potassium Content (kg/ha)                  -0.021327
#
#                             Phosphorus Content (kg/ha)  \
# pH Level                                      0.018209
# Organic Matter (%)                            0.004745
# Nitrogen Content (kg/ha)                      0.002912
# Phosphorus Content (kg/ha)                    1.000000
# ...

# %%
soil_data.isna().sum()
# Out:
# District                      0
# Soil Type                     0
# pH Level                      0
# Organic Matter (%)            0
# Nitrogen Content (kg/ha)      0
# Phosphorus Content (kg/ha)    0
# Potassium Content (kg/ha)     0
# dtype: int64

# %%
districts = soil_data['District'].unique()
soil_type = soil_data['Soil Type'].unique()

# %%
for i in soil_data.columns[2:]:
    plt.figure(figsize = (10,7))
    pH = soil_data.groupby(['District']).sum()[i]
    plt.pie(pH,labels = districts,autopct = '%.2f%%')
    plt.title('Percentage of '+i+' in different districts')
    plt.show()

# %%
for i in soil_data.columns[2:]:
    plt.figure(figsize = (10,7))
    pH = soil_data.groupby(['Soil Type']).sum()[i]
    plt.pie(pH,labels = soil_type,autopct = '%.2f%%')
    plt.title('Percentage of '+i+' in different soil types')
    plt.show()

# %% [markdown]
# # EDA on water storage

# %%
water_data = pd.read_csv('water_usage_data.csv')
water_data.head()
# Out:
#    District    Crop     Irrigation Method  Water Consumption (liters/hectare)  \
# 0   Udaipur  Garlic             Tube Well                        11609.330886
# 1  Bhilwara    Gram       Drip Irrigation                        12648.406038
# 2   Udaipur   Guava      Canal Irrigation                        10063.162448
# 3   Jodhpur  Barley  Sprinkler Irrigation                        10110.539993
# 4     Alwar    Gram      Canal Irrigation                         9320.451018
#
#    Water Availability (liters/hectare)
# 0                         11335.919980
# 1                         12091.900254
# 2                          9810.943169
# 3                         10754.217313
# 4                          8695.537819

# %%
water_data.describe()
# Out:
#        Water Consumption (liters/hectare)  Water Availability (liters/hectare)
# count                         1000.000000                          1000.000000
# mean                         10557.110759                         10543.621287
# std                           2835.083841                          2905.372578
# min                           4673.530139                          4505.257189
# 25%                           8238.226672                          8142.359044
# 50%                          10422.656935                         10524.479417
# 75%                          12808.359361                         12879.893934
# max                          18631.091327                         18489.171266

# %%
water_data.corr()
# Out:
#                                      Water Consumption (liters/hectare)  \
# Water Consumption (liters/hectare)                             1.000000
# Water Availability (liters/hectare)                            0.981122
#
#                                      Water Availability (liters/hectare)
# Water Consumption (liters/hectare)                              0.981122
# Water Availability (liters/hectare)                             1.000000

# %%
unique_district = water_data['District'].unique()
unique_crop = water_data['Crop'].unique()
unique_irrigation_method =water_data['Irrigation Method'].unique()

# %%
print(unique_district)
print(unique_crop)
print(unique_irrigation_method)
# Out:
# ['Udaipur' 'Bhilwara' 'Jodhpur' 'Alwar' 'Nagaur' 'Hanumangarh' 'Kota'
#  'Sri Ganganagar' 'Ajmer' 'Jaipur']
# ['Garlic' 'Gram' 'Guava' 'Barley' 'Bajra' 'Pulses' 'Citrus' 'Opium'
#  'Fenugreek' 'Tomato' 'Sugarcane' 'Chilli' 'Onion' 'Pomegranate'
#  'Oilseeds' 'Maize' 'Cumin' 'Cotton' 'Mango' 'Coriander' 'Wheat' 'Mustard'
#  'Fennel']
# ['Tube Well' 'Drip Irrigation' 'Canal Irrigation' 'Sprinkler Irrigation']

# %%
for i in water_data.columns[3:]:
    plt.figure(figsize = (10,7))
    pH = water_data.groupby(['District']).sum()[i]
    plt.pie(pH,labels = unique_district,autopct = '%.2f%%')
    plt.title('Percentage of '+i+' in different soil types')
    plt.show()

# %%
for i in water_data.columns[3:]:
    plt.figure(figsize = (10,7))
    pH = water_data.groupby(['Crop']).sum()[i]
    plt.pie(pH,labels = unique_crop,autopct = '%.2f%%',radius=1.5)
    plt.title('Percentage of '+i+' in different soil types')
    plt.show()

# %%
for i in water_data.columns[3:]:
    plt.figure(figsize = (10,7))
    pH = water_data.groupby(['Irrigation Method']).sum()[i]
    plt.pie(pH,labels = unique_irrigation_method,autopct = '%.2f%%')
    plt.title('Percentage of '+i+' in different soil types')
    plt.show()

# %%
arr3=[]
water_data[water_data["Water Consumption (liters/hectare)"]==water_data["Water Consumption (liters/hectare)"].min()]
for i in unique_district:
    x=water_data[water_data["District"]==i]
    sm=x["Water Availability (liters/hectare)"].sum()
    print(i,"=",sm)
    arr3.append(sm)
plt.figure(figsize=(25,7))
plt.title("District vs Water Availability ",fontsize=30)
plt.bar(unique_district,arr3,width=0.7,align="center",color="yellow")
plt.xlabel("District",color="b",fontweight="bold",fontsize=25)
plt.ylabel("Water Availability(liters/hectare)",color="b",fontweight="bold",fontsize=25)
# Out:
# Udaipur = 1235790.693991199
# Bhilwara = 1036133.1350752482
# Jodhpur = 937391.2747839467
# Alwar = 1067130.8013579065
# Nagaur = 1234247.4312292004
# Hanumangarh = 1081154.1873868145
# Kota = 1022186.619164818
# Sri Ganganagar = 971732.6907283118
# Ajmer = 919429.9870188814
# Jaipur = 1038424.4665535801
# Text(0, 0.5, 'Water Availability(liters/hectare)')

# %%
# Relation between water consumption and Water availability
plt.figure(figsize=(10,7))
plt.scatter(water_data["Water Consumption (liters/hectare)"],water_data["Water Availability (liters/hectare)"],c="indigo")
plt.title("Water consumption vs water availability",fontsize=25)
plt.xlabel("Water consumption",fontsize=15,c="r")
plt.ylabel("Water Avaulability",fontsize=15,c="r")
# Out:
# Text(0, 0.5, 'Water Avaulability')
